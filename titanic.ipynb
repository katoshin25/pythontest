# %% [markdown]
# # タイタニック復習
# ## 参考　udemy 実践　python データサイエンス

# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
sns.countplot('Sex',data=df)

# %%
sns.countplot('Pclass',data=df,hue='Sex')

# %%
def child(passenger):
    age,sex = passenger
    if age <16:
        return 'child'
    else:
        return sex
df['person'] = df[['Age','Sex']].apply(child,axis=1)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.countplot('Pclass',data=df,hue='person')

# %%
df['Age'].hist(bins=70)

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['person'].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
fig = sns.FacetGrid(df,hue='Sex',aspect = 4)
fig.map(sns.kdeplot,'Age',shade = True)
oldest = df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(df,hue='person',aspect = 4)
fig.map(sns.kdeplot,'Age',shade = True)
oldest = df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
fig = sns.FacetGrid(df,hue='Pclass',aspect = 4)
fig.map(sns.kdeplot,'Age',shade = True)
oldest = df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()

# %%
deck = df['Cabin'].dropna()

# %%
deck
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
# 21             D56
# 23              A6
# 27     C23 C25 C27
# 31             B78
# 52             D33
# 54             B30
# 55             C52
# 61             B28
# 62             C83
# 66             F33
# 75           F G73
# 88     C23 C25 C27
# 92             E31
# 96              A5
# 97         D10 D12
# 102            D26
# 110           C110
# 118        B58 B60
# 123           E101
# 124            D26
# 128          F E69
# 136            D47
# 137           C123
# 139            B86
# 148             F2
#           ...
# 751           E121
# 759            B77
# 763        B96 B98
# 765            D11
# 772            E77
# 776            F38
# 779             B3
# 781            B20
# 782             D6
# 789        B82 B84
# 796            D17
# 802        B96 B98
# 806            A36
# 809             E8
# 815           B102
# 820            B69
# ...

# %%
levels =[]
for level in deck:
    levels.append(level[0])

# %%
cabin_df = DataFrame(levels)
cabin_df.columns = ['Cabin']

# %%
cabin_df
# Out:
#     Cabin
# 0       C
# 1       C
# 2       E
# 3       G
# 4       C
# 5       D
# 6       A
# 7       C
# 8       B
# 9       D
# 10      B
# 11      C
# 12      B
# 13      C
# 14      F
# 15      F
# 16      C
# 17      E
# 18      A
# 19      D
# 20      D
# 21      C
# 22      B
# 23      E
# 24      D
# 25      F
# 26      D
# 27      C
# 28      B
# 29      F
# ..    ...
# 174     E
# 175     B
# 176     B
# 177     D
# 178     E
# 179     F
# 180     B
# 181     B
# 182     D
# 183     B
# 184     D
# 185     B
# 186     A
# 187     E
# 188     B
# 189     B
# 190     E
# 191     B
# 192     E
# 193     C
# 194     C
# 195     D
# 196     E
# 197     D
# 198     A
# 199     D
# 200     B
# 201     C
# 202     B
# 203     C
#
# [204 rows x 1 columns]

# %%
sns.countplot('Cabin',data=cabin_df,palette='winter_d',order=sorted(set(levels)))

# %%
cabin_df = cabin_df[cabin_df.Cabin != 'T']

# %%
sns.countplot('Cabin',data=cabin_df,palette='summer',order=sorted(set(cabin_df.Cabin)))

# %%
sns.countplot('Embarked', data =df,hue='Pclass')

# %%
from collections import Counter

# %%
Counter(df.Embarked)
# Out:
# Counter({'S': 644, 'C': 168, 'Q': 77, nan: 2})

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Alone']= df.Parch + df.SibSp

# %%
df['Alone']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       4
# 8       2
# 9       1
# 10      2
# 11      0
# 12      0
# 13      6
# 14      0
# 15      0
# 16      5
# 17      0
# 18      1
# 19      0
# 20      0
# 21      0
# 22      0
# 23      0
# 24      4
# 25      6
# 26      0
# 27      5
# 28      0
# 29      0
#        ..
# 861     1
# 862     0
# 863    10
# 864     0
# 865     0
# 866     1
# 867     0
# 868     0
# 869     2
# 870     0
# 871     2
# 872     0
# 873     0
# 874     1
# 875     0
# 876     0
# 877     0
# 878     0
# 879     1
# 880     1
# 881     0
# 882     0
# 883     0
# 884     0
# 885     5
# 886     0
# 887     0
# 888     3
# 889     0
# 890     0
# Name: Alone, Length: 891, dtype: int64

# %%
df['Alone'].loc[df['Alone']>0] = 'With Family'
df['Alone'].loc[df['Alone'] == 0] = 'Alone'
# Out:
# C:\Users\syoun\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
sns.countplot('Alone',data = df,palette='Blues')

# %%
df['Survivor'] = df.Survived.map({0:'no',1:'yes'})

# %%
sns.countplot('Survivor',data = df, palette = 'Set1')

# %%
sns.factorplot('Pclass','Survived',data = df,order=[1,2,3])

# %%
sns.factorplot('Pclass','Survived',data = df,order=[1,2,3],hue = 'person')

# %%
sns.lmplot('Age','Survived',data = df)

# %%
sns.lmplot('Age','Survived',data = df,hue = 'Pclass')

# %%
gene = [10,20,40,60,80]
sns.lmplot('Age','Survived',data = df,hue = 'Pclass', x_bins = gene)

# %%
sns.lmplot('Age','Survived',data = df,hue = 'Sex', x_bins = gene)
